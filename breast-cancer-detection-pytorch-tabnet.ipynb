# %% [markdown]
# <a href="https://www.kaggle.com/code/hamidjazayeriy/breast-cancer-detection-100-acc-pytorch-tabnet?scriptVersionId=184722569" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Installing and Importing Required Python Libraries

# %%
# !pip install pytorch_tabnet

import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from pytorch_tabnet.tab_model import TabNetClassifier
import torch
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from pytorch_tabnet) (1.23.5)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.10/site-packages (from pytorch_tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.10/site-packages (from pytorch_tabnet) (1.11.2)
# Requirement already satisfied: torch>=1.3 in /opt/conda/lib/python3.10/site-packages (from pytorch_tabnet) (2.0.0)
# Requirement already satisfied: tqdm>=4.36 in /opt/conda/lib/python3.10/site-packages (from pytorch_tabnet) (4.66.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit_learn>0.21->pytorch_tabnet) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit_learn>0.21->pytorch_tabnet) (3.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch_tabnet) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch_tabnet) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch_tabnet) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch_tabnet) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch_tabnet) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3->pytorch_tabnet) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3->pytorch_tabnet) (1.3.0)
# Installing collected packages: pytorch_tabnet
# Successfully installed pytorch_tabnet-4.1.0
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Reading the dataset

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(f" The path to access data is: \n  {os.path.join(dirname, filename)}")
        
data=pd.read_csv("/kaggle/input/breast-cancer/breast-cancer-wisconsin-data_data.csv")

print(f"There are {data.shape[0]} rows and {data.shape[1]} columns in the dataset {data.shape}")
# Out:
#  The path to access data is:
#   /kaggle/input/breast-cancer/breast-cancer-wisconsin-data_data.csv
# There are 569 rows and 33 columns in the dataset (569, 33)

# %% [markdown]
# # Preprocessing

# %%
##Columns
#data.columns

##Info About Data columns
#data.info()

##Head
#data.head()

#Finding Null Values
#data.isnull().mean()*100

##Finding Duplicates
#data.duplicated().sum()

#Removing unnecessary columns
data.drop(columns={'id','Unnamed: 32'},inplace=True)

# %% [markdown]
# # Label and Feature Encoding
# Target values should be transform to a binary class {0,1}

# %%
Target = data['diagnosis']
Features = data.drop(columns={'diagnosis'})

encoder=LabelEncoder()
Target = encoder.fit_transform(Target)
print("class Labels :", encoder.classes_)

scaler = StandardScaler()
Features = scaler.fit_transform(Features).squeeze()
Features.shape, Target.shape
# Out:
# class Labels : ['B' 'M']
# ((569, 30), (569,))

# %% [markdown]
# # Split Train and Test sets

# %%
#Train_Test_Split
X_train,X_test,y_train,y_test=train_test_split (Features,Target,test_size=0.3, random_state=41)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((398, 30), (171, 30), (398,), (171,))

# %% [markdown]
# # Model definition

# %%
# define the model
TN_model= TabNetClassifier(optimizer_fn=torch.optim.Adam,
                       scheduler_params={"step_size":10, 
                                         "gamma":0.95},
                       scheduler_fn=torch.optim.lr_scheduler.StepLR,
                      )

# %% [markdown]
# # Fitting the Model

# %%
# fit the model 
TN_model.fit(
    X_train ,y_train,
    eval_set=[(X_train, y_train), (X_test , y_test)],
    eval_name=['train', 'test'],
    eval_metric=['auc','balanced_accuracy'],
    max_epochs=200, patience=60,
    batch_size=512, virtual_batch_size=512,
    num_workers=0,
    weights=1,
    drop_last=False
)
# Out:
# epoch 0  | loss: 1.02706 | train_auc: 0.77942 | train_balanced_accuracy: 0.74184 | test_auc: 0.82116 | test_balanced_accuracy: 0.74255 |  0:00:00s
# epoch 1  | loss: 0.71808 | train_auc: 0.82398 | train_balanced_accuracy: 0.80441 | test_auc: 0.86736 | test_balanced_accuracy: 0.82988 |  0:00:00s
# epoch 2  | loss: 0.63985 | train_auc: 0.84693 | train_balanced_accuracy: 0.80221 | test_auc: 0.87064 | test_balanced_accuracy: 0.83077 |  0:00:00s
# epoch 3  | loss: 0.55169 | train_auc: 0.88693 | train_balanced_accuracy: 0.82669 | test_auc: 0.90656 | test_balanced_accuracy: 0.838   |  0:00:00s
# epoch 4  | loss: 0.53392 | train_auc: 0.88868 | train_balanced_accuracy: 0.83092 | test_auc: 0.90134 | test_balanced_accuracy: 0.82526 |  0:00:00s
# epoch 5  | loss: 0.52709 | train_auc: 0.90983 | train_balanced_accuracy: 0.85429 | test_auc: 0.9377  | test_balanced_accuracy: 0.86714 |  0:00:01s
# epoch 6  | loss: 0.39804 | train_auc: 0.93179 | train_balanced_accuracy: 0.86036 | test_auc: 0.95544 | test_balanced_accuracy: 0.87802 |  0:00:01s
# epoch 7  | loss: 0.41619 | train_auc: 0.93726 | train_balanced_accuracy: 0.84786 | test_auc: 0.95887 | test_balanced_accuracy: 0.92355 |  0:00:01s
# epoch 8  | loss: 0.32589 | train_auc: 0.94509 | train_balanced_accuracy: 0.86331 | test_auc: 0.96289 | test_balanced_accuracy: 0.93264 |  0:00:01s
# epoch 9  | loss: 0.32933 | train_auc: 0.95152 | train_balanced_accuracy: 0.86994 | test_auc: 0.96706 | test_balanced_accuracy: 0.9117  |  0:00:01s
# epoch 10 | loss: 0.28157 | train_auc: 0.95678 | train_balanced_accuracy: 0.86994 | test_auc: 0.96975 | test_balanced_accuracy: 0.919   |  0:00:01s
# epoch 11 | loss: 0.25881 | train_auc: 0.96171 | train_balanced_accuracy: 0.88061 | test_auc: 0.95931 | test_balanced_accuracy: 0.93264 |  0:00:01s
# epoch 12 | loss: 0.25853 | train_auc: 0.96951 | train_balanced_accuracy: 0.89459 | test_auc: 0.97645 | test_balanced_accuracy: 0.95358 |  0:00:01s
# epoch 13 | loss: 0.2309  | train_auc: 0.97348 | train_balanced_accuracy: 0.90047 | test_auc: 0.97511 | test_balanced_accuracy: 0.94083 |  0:00:01s
# epoch 14 | loss: 0.18445 | train_auc: 0.97737 | train_balanced_accuracy: 0.90581 | test_auc: 0.98063 | test_balanced_accuracy: 0.96542 |  0:00:01s
# epoch 15 | loss: 0.1449  | train_auc: 0.97651 | train_balanced_accuracy: 0.91372 | test_auc: 0.97571 | test_balanced_accuracy: 0.96632 |  0:00:01s
# epoch 16 | loss: 0.16025 | train_auc: 0.98013 | train_balanced_accuracy: 0.91777 | test_auc: 0.98152 | test_balanced_accuracy: 0.96542 |  0:00:01s
# epoch 17 | loss: 0.13409 | train_auc: 0.98289 | train_balanced_accuracy: 0.91777 | test_auc: 0.98629 | test_balanced_accuracy: 0.96542 |  0:00:01s
# epoch 18 | loss: 0.1174  | train_auc: 0.98437 | train_balanced_accuracy: 0.91574 | test_auc: 0.9921  | test_balanced_accuracy: 0.97906 |  0:00:01s
# epoch 19 | loss: 0.0857  | train_auc: 0.98466 | train_balanced_accuracy: 0.9117  | test_auc: 0.99389 | test_balanced_accuracy: 0.98361 |  0:00:01s
# epoch 20 | loss: 0.11431 | train_auc: 0.98515 | train_balanced_accuracy: 0.91703 | test_auc: 0.99568 | test_balanced_accuracy: 0.97541 |  0:00:01s
# epoch 21 | loss: 0.09238 | train_auc: 0.98587 | train_balanced_accuracy: 0.91703 | test_auc: 0.99687 | test_balanced_accuracy: 0.97541 |  0:00:01s
# epoch 22 | loss: 0.1045  | train_auc: 0.98673 | train_balanced_accuracy: 0.92696 | test_auc: 0.98346 | test_balanced_accuracy: 0.97086 |  0:00:01s
# epoch 23 | loss: 0.06629 | train_auc: 0.9848  | train_balanced_accuracy: 0.9323  | test_auc: 0.99642 | test_balanced_accuracy: 0.97086 |  0:00:01s
# epoch 24 | loss: 0.09685 | train_auc: 0.98429 | train_balanced_accuracy: 0.93359 | test_auc: 0.99821 | test_balanced_accuracy: 0.97906 |  0:00:01s
# epoch 25 | loss: 0.07108 | train_auc: 0.98437 | train_balanced_accuracy: 0.9369  | test_auc: 0.99434 | test_balanced_accuracy: 0.97906 |  0:00:02s
# epoch 26 | loss: 0.07142 | train_auc: 0.98528 | train_balanced_accuracy: 0.9415  | test_auc: 0.99762 | test_balanced_accuracy: 0.97906 |  0:00:02s
# epoch 27 | loss: 0.07776 | train_auc: 0.98643 | train_balanced_accuracy: 0.94609 | test_auc: 0.99866 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 28 | loss: 0.07774 | train_auc: 0.98718 | train_balanced_accuracy: 0.94738 | test_auc: 0.99851 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 29 | loss: 0.07425 | train_auc: 0.98756 | train_balanced_accuracy: 0.954   | test_auc: 0.99821 | test_balanced_accuracy: 0.98271 |  0:00:02s
# epoch 30 | loss: 0.06266 | train_auc: 0.98721 | train_balanced_accuracy: 0.94941 | test_auc: 0.99747 | test_balanced_accuracy: 0.97817 |  0:00:02s
# epoch 31 | loss: 0.0666  | train_auc: 0.987   | train_balanced_accuracy: 0.94867 | test_auc: 0.99821 | test_balanced_accuracy: 0.97817 |  0:00:02s
# epoch 32 | loss: 0.07566 | train_auc: 0.98625 | train_balanced_accuracy: 0.94867 | test_auc: 0.99821 | test_balanced_accuracy: 0.97817 |  0:00:02s
# epoch 33 | loss: 0.04086 | train_auc: 0.98507 | train_balanced_accuracy: 0.95069 | test_auc: 0.99747 | test_balanced_accuracy: 0.97817 |  0:00:02s
# epoch 34 | loss: 0.04239 | train_auc: 0.98523 | train_balanced_accuracy: 0.94738 | test_auc: 0.99687 | test_balanced_accuracy: 0.97817 |  0:00:02s
# epoch 35 | loss: 0.03671 | train_auc: 0.98493 | train_balanced_accuracy: 0.94738 | test_auc: 0.99613 | test_balanced_accuracy: 0.98271 |  0:00:02s
# epoch 36 | loss: 0.1229  | train_auc: 0.98504 | train_balanced_accuracy: 0.94941 | test_auc: 0.99523 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 37 | loss: 0.04667 | train_auc: 0.9852  | train_balanced_accuracy: 0.94812 | test_auc: 0.99404 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 38 | loss: 0.08978 | train_auc: 0.98563 | train_balanced_accuracy: 0.94481 | test_auc: 0.99449 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 39 | loss: 0.11011 | train_auc: 0.98635 | train_balanced_accuracy: 0.94812 | test_auc: 0.99419 | test_balanced_accuracy: 0.98271 |  0:00:02s
# epoch 40 | loss: 0.0498  | train_auc: 0.98732 | train_balanced_accuracy: 0.95143 | test_auc: 0.99434 | test_balanced_accuracy: 0.98271 |  0:00:02s
# epoch 41 | loss: 0.0337  | train_auc: 0.98852 | train_balanced_accuracy: 0.95143 | test_auc: 0.99374 | test_balanced_accuracy: 0.98271 |  0:00:02s
# epoch 42 | loss: 0.03109 | train_auc: 0.9893  | train_balanced_accuracy: 0.95143 | test_auc: 0.99374 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 43 | loss: 0.03896 | train_auc: 0.99003 | train_balanced_accuracy: 0.95805 | test_auc: 0.99374 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 44 | loss: 0.03425 | train_auc: 0.99094 | train_balanced_accuracy: 0.95805 | test_auc: 0.99463 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 45 | loss: 0.03383 | train_auc: 0.99177 | train_balanced_accuracy: 0.96008 | test_auc: 0.99463 | test_balanced_accuracy: 0.98726 |  0:00:02s
# epoch 46 | loss: 0.04734 | train_auc: 0.99182 | train_balanced_accuracy: 0.95805 | test_auc: 0.99478 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 47 | loss: 0.05199 | train_auc: 0.9919  | train_balanced_accuracy: 0.95934 | test_auc: 0.99538 | test_balanced_accuracy: 0.98271 |  0:00:03s
# epoch 48 | loss: 0.02972 | train_auc: 0.99172 | train_balanced_accuracy: 0.96265 | test_auc: 0.99583 | test_balanced_accuracy: 0.98271 |  0:00:03s
# epoch 49 | loss: 0.02949 | train_auc: 0.99163 | train_balanced_accuracy: 0.96265 | test_auc: 0.99598 | test_balanced_accuracy: 0.98271 |  0:00:03s
# epoch 50 | loss: 0.03841 | train_auc: 0.99161 | train_balanced_accuracy: 0.96468 | test_auc: 0.99583 | test_balanced_accuracy: 0.98271 |  0:00:03s
# epoch 51 | loss: 0.02648 | train_auc: 0.99161 | train_balanced_accuracy: 0.96468 | test_auc: 0.99598 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 52 | loss: 0.04075 | train_auc: 0.99279 | train_balanced_accuracy: 0.96468 | test_auc: 0.99568 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 53 | loss: 0.01593 | train_auc: 0.99413 | train_balanced_accuracy: 0.97204 | test_auc: 0.99642 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 54 | loss: 0.04483 | train_auc: 0.99469 | train_balanced_accuracy: 0.97608 | test_auc: 0.99657 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 55 | loss: 0.06647 | train_auc: 0.99488 | train_balanced_accuracy: 0.97406 | test_auc: 0.99717 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 56 | loss: 0.03586 | train_auc: 0.99501 | train_balanced_accuracy: 0.97001 | test_auc: 0.99702 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 57 | loss: 0.02377 | train_auc: 0.99536 | train_balanced_accuracy: 0.97792 | test_auc: 0.99747 | test_balanced_accuracy: 0.98726 |  0:00:03s
# epoch 58 | loss: 0.03913 | train_auc: 0.99558 | train_balanced_accuracy: 0.97387 | test_auc: 0.99776 | test_balanced_accuracy: 0.97817 |  0:00:03s
# epoch 59 | loss: 0.01259 | train_auc: 0.99544 | train_balanced_accuracy: 0.97185 | test_auc: 0.99881 | test_balanced_accuracy: 0.97817 |  0:00:03s
# epoch 60 | loss: 0.02986 | train_auc: 0.99533 | train_balanced_accuracy: 0.97442 | test_auc: 0.99851 | test_balanced_accuracy: 0.97362 |  0:00:03s
# epoch 61 | loss: 0.05048 | train_auc: 0.99547 | train_balanced_accuracy: 0.9724  | test_auc: 0.99896 | test_balanced_accuracy: 0.96908 |  0:00:03s
# epoch 62 | loss: 0.05337 | train_auc: 0.99568 | train_balanced_accuracy: 0.97442 | test_auc: 0.99955 | test_balanced_accuracy: 0.97727 |  0:00:03s
# epoch 63 | loss: 0.03726 | train_auc: 0.99576 | train_balanced_accuracy: 0.97442 | test_auc: 1.0     | test_balanced_accuracy: 0.97727 |  0:00:03s
# epoch 64 | loss: 0.03539 | train_auc: 0.99576 | train_balanced_accuracy: 0.97847 | test_auc: 1.0     | test_balanced_accuracy: 0.97727 |  0:00:03s
# epoch 65 | loss: 0.03018 | train_auc: 0.99574 | train_balanced_accuracy: 0.98049 | test_auc: 1.0     | test_balanced_accuracy: 0.98182 |  0:00:03s
# epoch 66 | loss: 0.02569 | train_auc: 0.9956  | train_balanced_accuracy: 0.98252 | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:03s
# epoch 67 | loss: 0.03213 | train_auc: 0.99563 | train_balanced_accuracy: 0.98252 | test_auc: 1.0     | test_balanced_accuracy: 0.99091 |  0:00:03s
# epoch 68 | loss: 0.06899 | train_auc: 0.99568 | train_balanced_accuracy: 0.98528 | test_auc: 1.0     | test_balanced_accuracy: 0.99091 |  0:00:04s
# epoch 69 | loss: 0.02885 | train_auc: 0.99587 | train_balanced_accuracy: 0.98602 | test_auc: 1.0     | test_balanced_accuracy: 0.99091 |  0:00:04s
# epoch 70 | loss: 0.01337 | train_auc: 0.99576 | train_balanced_accuracy: 0.98602 | test_auc: 1.0     | test_balanced_accuracy: 0.99545 |  0:00:04s
# epoch 71 | loss: 0.0408  | train_auc: 0.99584 | train_balanced_accuracy: 0.98602 | test_auc: 1.0     | test_balanced_accuracy: 1.0     |  0:00:04s
# epoch 72 | loss: 0.02554 | train_auc: 0.99582 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.99545 |  0:00:04s
# epoch 73 | loss: 0.03489 | train_auc: 0.99579 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 74 | loss: 0.02331 | train_auc: 0.99662 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 75 | loss: 0.02577 | train_auc: 0.99783 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 76 | loss: 0.01661 | train_auc: 0.99847 | train_balanced_accuracy: 0.98933 | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 77 | loss: 0.01174 | train_auc: 0.99925 | train_balanced_accuracy: 0.98933 | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 78 | loss: 0.04524 | train_auc: 0.9993  | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.98636 |  0:00:04s
# epoch 79 | loss: 0.02584 | train_auc: 0.99946 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 80 | loss: 0.02242 | train_auc: 0.99957 | train_balanced_accuracy: 0.98859 | test_auc: 0.9997  | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 81 | loss: 0.01918 | train_auc: 0.99962 | train_balanced_accuracy: 0.98657 | test_auc: 0.99985 | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 82 | loss: 0.04672 | train_auc: 0.99968 | train_balanced_accuracy: 0.9873  | test_auc: 1.0     | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 83 | loss: 0.0108  | train_auc: 0.99976 | train_balanced_accuracy: 0.98528 | test_auc: 0.99955 | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 84 | loss: 0.00841 | train_auc: 0.99973 | train_balanced_accuracy: 0.98528 | test_auc: 0.9994  | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 85 | loss: 0.01673 | train_auc: 0.99976 | train_balanced_accuracy: 0.99264 | test_auc: 0.99955 | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 86 | loss: 0.02477 | train_auc: 0.99976 | train_balanced_accuracy: 0.99264 | test_auc: 0.99955 | test_balanced_accuracy: 0.97727 |  0:00:04s
# epoch 87 | loss: 0.00633 | train_auc: 0.99976 | train_balanced_accuracy: 0.99062 | test_auc: 0.99955 | test_balanced_accuracy: 0.98182 |  0:00:04s
# epoch 88 | loss: 0.00948 | train_auc: 0.99968 | train_balanced_accuracy: 0.99062 | test_auc: 0.99955 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 89 | loss: 0.0166  | train_auc: 0.99962 | train_balanced_accuracy: 0.99062 | test_auc: 0.99955 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 90 | loss: 0.01898 | train_auc: 0.99962 | train_balanced_accuracy: 0.98859 | test_auc: 0.99925 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 91 | loss: 0.03511 | train_auc: 0.99971 | train_balanced_accuracy: 0.98859 | test_auc: 0.99911 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 92 | loss: 0.01151 | train_auc: 0.99968 | train_balanced_accuracy: 0.98454 | test_auc: 0.99896 | test_balanced_accuracy: 0.97727 |  0:00:05s
# epoch 93 | loss: 0.00711 | train_auc: 0.99965 | train_balanced_accuracy: 0.98252 | test_auc: 0.99866 | test_balanced_accuracy: 0.97727 |  0:00:05s
# epoch 94 | loss: 0.00475 | train_auc: 0.99968 | train_balanced_accuracy: 0.98252 | test_auc: 0.99836 | test_balanced_accuracy: 0.97727 |  0:00:05s
# epoch 95 | loss: 0.0167  | train_auc: 0.99973 | train_balanced_accuracy: 0.98381 | test_auc: 0.99776 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 96 | loss: 0.01112 | train_auc: 0.99976 | train_balanced_accuracy: 0.98178 | test_auc: 0.99732 | test_balanced_accuracy: 0.96818 |  0:00:05s
# epoch 97 | loss: 0.03154 | train_auc: 0.99987 | train_balanced_accuracy: 0.98583 | test_auc: 0.99821 | test_balanced_accuracy: 0.96818 |  0:00:05s
# epoch 98 | loss: 0.01718 | train_auc: 0.99987 | train_balanced_accuracy: 0.98583 | test_auc: 0.99866 | test_balanced_accuracy: 0.96818 |  0:00:05s
# epoch 99 | loss: 0.00533 | train_auc: 0.99992 | train_balanced_accuracy: 0.98178 | test_auc: 0.99881 | test_balanced_accuracy: 0.96818 |  0:00:05s
# epoch 100| loss: 0.00821 | train_auc: 0.99987 | train_balanced_accuracy: 0.98381 | test_auc: 0.99881 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 101| loss: 0.01342 | train_auc: 0.99997 | train_balanced_accuracy: 0.98381 | test_auc: 0.99881 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 102| loss: 0.02278 | train_auc: 0.99997 | train_balanced_accuracy: 0.98583 | test_auc: 0.99896 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 103| loss: 0.00593 | train_auc: 1.0     | train_balanced_accuracy: 0.98988 | test_auc: 0.99881 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 104| loss: 0.02187 | train_auc: 1.0     | train_balanced_accuracy: 0.99393 | test_auc: 0.99732 | test_balanced_accuracy: 0.97273 |  0:00:05s
# epoch 105| loss: 0.00529 | train_auc: 1.0     | train_balanced_accuracy: 1.0     | test_auc: 0.99851 | test_balanced_accuracy: 0.97727 |  0:00:05s
# epoch 106| loss: 0.00348 | train_auc: 1.0     | train_balanced_accuracy: 1.0     | test_auc: 0.99851 | test_balanced_accuracy: 0.97727 |  0:00:05s
# epoch 107| loss: 0.02043 | train_auc: 0.99995 | train_balanced_accuracy: 0.99669 | test_auc: 0.99911 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 108| loss: 0.03948 | train_auc: 0.99995 | train_balanced_accuracy: 0.99338 | test_auc: 0.99925 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 109| loss: 0.00872 | train_auc: 0.99979 | train_balanced_accuracy: 0.99338 | test_auc: 0.99925 | test_balanced_accuracy: 0.98182 |  0:00:05s
# epoch 110| loss: 0.00516 | train_auc: 0.99957 | train_balanced_accuracy: 0.99135 | test_auc: 0.99925 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 111| loss: 0.00323 | train_auc: 0.99885 | train_balanced_accuracy: 0.99135 | test_auc: 0.99911 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 112| loss: 0.00832 | train_auc: 0.99882 | train_balanced_accuracy: 0.99466 | test_auc: 0.99911 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 113| loss: 0.00885 | train_auc: 0.99882 | train_balanced_accuracy: 0.99466 | test_auc: 0.99911 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 114| loss: 0.027   | train_auc: 0.99898 | train_balanced_accuracy: 0.99466 | test_auc: 0.99866 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 115| loss: 0.01048 | train_auc: 0.99906 | train_balanced_accuracy: 0.99466 | test_auc: 0.99866 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 116| loss: 0.01473 | train_auc: 0.99995 | train_balanced_accuracy: 0.99595 | test_auc: 0.99851 | test_balanced_accuracy: 0.98636 |  0:00:06s
# epoch 117| loss: 0.00601 | train_auc: 1.0     | train_balanced_accuracy: 0.99393 | test_auc: 0.99821 | test_balanced_accuracy: 0.98182 |  0:00:06s
# epoch 118| loss: 0.00369 | train_auc: 1.0     | train_balanced_accuracy: 0.99393 | test_auc: 0.99747 | test_balanced_accuracy: 0.97362 |  0:00:06s
# epoch 119| loss: 0.00573 | train_auc: 1.0     | train_balanced_accuracy: 0.99393 | test_auc: 0.99702 | test_balanced_accuracy: 0.97362 |  0:00:06s
# epoch 120| loss: 0.00912 | train_auc: 0.99987 | train_balanced_accuracy: 0.9919  | test_auc: 0.99762 | test_balanced_accuracy: 0.97727 |  0:00:06s
# epoch 121| loss: 0.02602 | train_auc: 0.99981 | train_balanced_accuracy: 0.9919  | test_auc: 0.99568 | test_balanced_accuracy: 0.97727 |  0:00:06s
# epoch 122| loss: 0.00373 | train_auc: 0.99979 | train_balanced_accuracy: 0.99393 | test_auc: 0.99523 | test_balanced_accuracy: 0.97727 |  0:00:06s
# epoch 123| loss: 0.03667 | train_auc: 0.99997 | train_balanced_accuracy: 0.99393 | test_auc: 0.99493 | test_balanced_accuracy: 0.98636 |  0:00:06s
# epoch 124| loss: 0.01438 | train_auc: 1.0     | train_balanced_accuracy: 0.99595 | test_auc: 0.99449 | test_balanced_accuracy: 0.98636 |  0:00:06s
# epoch 125| loss: 0.00484 | train_auc: 1.0     | train_balanced_accuracy: 0.99595 | test_auc: 0.99449 | test_balanced_accuracy: 0.98636 |  0:00:06s
# epoch 126| loss: 0.01525 | train_auc: 1.0     | train_balanced_accuracy: 0.99595 | test_auc: 0.99478 | test_balanced_accuracy: 0.99091 |  0:00:06s
# epoch 127| loss: 0.01031 | train_auc: 1.0     | train_balanced_accuracy: 0.99595 | test_auc: 0.99493 | test_balanced_accuracy: 0.98636 |  0:00:06s
# epoch 128| loss: 0.06837 | train_auc: 1.0     | train_balanced_accuracy: 1.0     | test_auc: 0.99583 | test_balanced_accuracy: 0.99091 |  0:00:06s
# epoch 129| loss: 0.08758 | train_auc: 1.0     | train_balanced_accuracy: 1.0     | test_auc: 0.99642 | test_balanced_accuracy: 0.99091 |  0:00:06s
# epoch 130| loss: 0.01082 | train_auc: 1.0     | train_balanced_accuracy: 1.0     | test_auc: 0.99657 | test_balanced_accuracy: 0.99091 |  0:00:06s
# epoch 131| loss: 0.0098  | train_auc: 0.99995 | train_balanced_accuracy: 0.99669 | test_auc: 0.99717 | test_balanced_accuracy: 0.99091 |  0:00:07s
#
# Early stopping occurred at epoch 131 with best_epoch = 71 and best_test_balanced_accuracy = 1.0
# /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# # Test the Model

# %%
y_pred = TN_model.predict(X_test)
Acc = accuracy_score(y_test, y_pred)

print("\n================= Test Result ========================")  
print(f"Accuracy: %{100*Acc:6.2f}  ")
print("_______________________________________________________\n Classification Report:")
print(classification_report(y_test, y_pred))
print("_______________________________________________________\n Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# ================= Test Result ========================
# Accuracy: %100.00
# _______________________________________________________
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       110
#            1       1.00      1.00      1.00        61
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
#
# _______________________________________________________
#  Confusion Matrix:
# [[110   0]
#  [  0  61]]

# %% [markdown]
# # Finding the best random state
# The best resualt can be gained at random_state = 41
